# %%
# ====================== [QUICK & EFFECTIVE CIFAR-10 MODEL] ======================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
import time

# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)

print("⚡ Using TensorFlow", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# ====================== [1. QUICK DATA LOADING] ======================
print("\n📥 Loading CIFAR-10...")
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Quick validation split
val_split = 0.1
val_samples = int(len(x_train) * val_split)
x_val, y_val = x_train[-val_samples:], y_train[-val_samples:]
x_train, y_train = x_train[:-val_samples], y_train[:-val_samples]

print(f"Train: {x_train.shape[0]}, Val: {x_val.shape[0]}, Test: {x_test.shape[0]}")

# ====================== [2. EFFICIENT MODEL - CUSTOM VGG STYLE] ======================
print("\n🏗️ Building efficient model...")

def build_efficient_cifar10_model():
    """Compact but powerful model for CIFAR-10"""
    model = keras.Sequential([
        # Input: 32x32x3

        # Block 1
        layers.Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3)),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(32, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 2
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Dense layers
        layers.Flatten(),
        layers.Dense(256, kernel_regularizer=regularizers.l2(1e-4)),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(128, kernel_regularizer=regularizers.l2(1e-4)),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        # Output
        layers.Dense(10, activation='softmax')
    ])
    return model

model = build_efficient_cifar10_model()

# Quick compile
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# ====================== [3. SIMPLE BUT EFFECTIVE AUGMENTATION] ======================
print("\n🔄 Creating simple augmentation...")
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Minimal augmentation for speed
datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)

datagen.fit(x_train)

# ====================== [4. FAST TRAINING WITH CALLBACKS] ======================
print("\n⚡ Starting fast training...")

callbacks = [
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),
    EarlyStopping(
        monitor='val_accuracy',
        patience=8,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        'fast_cifar10_best.h5',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=0
    )
]

# Start timer
start_time = time.time()

# Train with augmentation
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=128),  # Larger batch for speed
    steps_per_epoch=len(x_train) // 128,
    epochs=30,
    validation_data=(x_val, y_val),
    callbacks=callbacks,
    verbose=1
)

training_time = time.time() - start_time
print(f"\n⏱️ Training completed in {training_time/60:.1f} minutes")

# ====================== [5. QUICK EVALUATION] ======================
print("\n📊 Evaluating model...")

# Load best weights
if tf.io.gfile.exists('fast_cifar10_best.h5'):
    model.load_weights('fast_cifar10_best.h5')
    print("✅ Loaded best model")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

print(f"\n{'='*50}")
print(f"🎯 TEST RESULTS:")
print(f"   Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)")
print(f"   Loss:     {test_loss:.4f}")
print(f"{'='*50}")

# ====================== [6. MINIMAL VISUALIZATION] ======================
print("\n📈 Quick visualization...")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy plot
ax1.plot(history.history['accuracy'], label='Train', linewidth=2)
ax1.plot(history.history['val_accuracy'], label='Val', linewidth=2)
ax1.axhline(y=0.73, color='r', linestyle='--', alpha=0.7, label='73% Target')
ax1.set_title(f'Accuracy (Final: {test_acc*100:.2f}%)', fontsize=14)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_ylim([0.5, 1.0])

# Loss plot
ax2.plot(history.history['loss'], label='Train', linewidth=2)
ax2.plot(history.history['val_loss'], label='Val', linewidth=2)
ax2.set_title('Loss', fontsize=14)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# ====================== [7. PERFORMANCE ANALYSIS] ======================
print("\n📋 Performance Analysis:")
print("-" * 40)

final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
overfit_gap = final_train_acc - final_val_acc

print(f"Train Accuracy:   {final_train_acc:.4f}")
print(f"Val Accuracy:     {final_val_acc:.4f}")
print(f"Test Accuracy:    {test_acc:.4f}")
print(f"Overfitting Gap:  {overfit_gap:.4f}")

# Check target
if test_acc >= 0.73:
    print(f"\n🎉 SUCCESS! Target achieved! ({test_acc*100:.2f}%)")
elif test_acc >= 0.72:
    print(f"\n✅ Close! {test_acc*100:.2f}% - Almost there!")
    print(f"   Need +{(0.73-test_acc)*100:.2f}% more")
else:
    print(f"\n📈 Current: {test_acc*100:.2f}%")
    print(f"   Need +{(0.73-test_acc)*100:.2f}% to reach 73%")

# ====================== [8. QUICK ENSEMBLE BOOST (OPTIONAL)] ======================
if test_acc < 0.73:
    print("\n🔄 Trying one more trick: Quick ensemble...")

    # Train 2 more models quickly
    models = [model]
    for i in range(2):
        print(f"\nTraining ensemble model {i+1}/2...")
        model_temp = build_efficient_cifar10_model()
        model_temp.compile(
            optimizer=optimizers.Adam(learning_rate=0.0005),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        # Quick training
        model_temp.fit(
            x_train, y_train,
            batch_size=128,
            epochs=10,
            validation_data=(x_val, y_val),
            verbose=0
        )
        models.append(model_temp)

    # Ensemble predictions
    predictions = []
    for m in models:
        pred = m.predict(x_test, verbose=0)
        predictions.append(pred)

    # Average predictions
    ensemble_pred = np.mean(predictions, axis=0)
    ensemble_acc = np.mean(np.argmax(ensemble_pred, axis=1) == np.argmax(y_test, axis=1))

    print(f"\n📊 Ensemble Results:")
    print(f"   Single model: {test_acc*100:.2f}%")
    print(f"   3-model ensemble: {ensemble_acc*100:.2f}%")
    print(f"   Improvement: +{(ensemble_acc-test_acc)*100:.2f}%")

    if ensemble_acc >= 0.73:
        print("🎉 ENSEMBLE ACHIEVED TARGET!")

# ====================== [9. SAVE & FINALIZE] ======================
print("\n💾 Saving model...")
model.save('cifar10_fast_final.h5')
print("✅ Model saved as 'cifar10_fast_final.h5'")

print("\n" + "="*50)
print("✅ TRAINING COMPLETE")
print("="*50)
# Out:
# ⚡ Using TensorFlow 2.19.0
# GPU Available: []
#
# 📥 Loading CIFAR-10...
# Train: 45000, Val: 5000, Test: 10000
#
# 🏗️ Building efficient model...
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_38 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_40 (Activation)      │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
print("Hello World")
# Out:
# Hello World

# %%
# 1. Save the champion model
model.save('cifar10_77pt54.keras')
print("✅ Saved: cifar10_77pt54.keras")

# 2. Save the winning recipe
with open('champion_recipe.txt', 'w') as f:
    f.write("=== CIFAR-10 CHAMPION (77.54%) ===\n\n")
    f.write("MODEL FILE: cifar10_77pt54.keras\n")
    f.write("ACCURACY: 0.7754 (77.54%)\n")
    f.write("LOSS: 0.7085\n")
    f.write("TIME: 121.8 minutes\n\n")
    f.write("HYPERPARAMETERS THAT WORKED:\n")
    f.write("- Batch size: 128\n")
    f.write("- Learning rate: 0.001\n")
    f.write("- Epochs: 30 (early stopped)\n")
    f.write("- Optimizer: Adam\n")
    f.write("- Dropout: 0.25 (conv), 0.5 (dense)\n")
    f.write("- Augmentation: flip, rotate, shift\n")

print("✅ Saved: champion_recipe.txt")

# 3. Download just these 2
from google.colab import files
files.download('cifar10_77pt54.keras')
files.download('champion_recipe.txt')
# Out:
# ✅ Saved: cifar10_77pt54.keras
# ✅ Saved: champion_recipe.txt
